# %% [markdown]
# Syntax for

# %%
for nilai in sequence:
  # blok kode for

# %%
listkota = ['Jakarta', 'Surabaya', 'Depok', 'Bekasi', 'Solo', 'Jogjakarta', 'Semarang', 'Makassar']

for kota in listkota:
  print(kota)
# Out:
# Jakarta
# Surabaya
# Depok
# Bekasi
# Solo
# Jogjakarta
# Semarang
# Makassar

# %%
listkota = ['Jakarta', 'Surabaya', 'Depok', 'Bekasi', 'Solo', 'Jogjakarta', 'Semarang', 'Makassar']

for i, kota in enumerate(listkota):
  print(i, kota)
# Out:
# 0 Jakarta
# 1 Surabaya
# 2 Depok
# 3 Bekasi
# 4 Solo
# 5 Jogjakarta
# 6 Semarang
# 7 Makassar

# %%
## 0 sampai 4

for i in range(5):
  print("Perulangan ke -", i)
# Out:
# Perulangan ke - 0
# Perulangan ke - 1
# Perulangan ke - 2
# Perulangan ke - 3
# Perulangan ke - 4

# %%
## 10 sampai 15

for i in range(10, 16):
  print('1 =', i)
# Out:
# 1 = 10
# 1 = 11
# 1 = 12
# 1 = 13
# 1 = 14
# 1 = 15

# %%
## Bilangan genap kelipatan 2

for i in range(2, 12, 2):
  print('i =', i)
# Out:
# i = 2
# i = 4
# i = 6
# i = 8
# i = 10

# %%
## Bilangan ganjil kelipatan 2

for bilangan_ganjil in range(1, 12, 2):
  print(bilangan_ganjil)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %% [markdown]
# For dengan tuple

# %%
tupleBuah = ('Mangga', 'Anggur', 'Apel', 'Melon')

for buah in tupleBuah:
  print(buah)
# Out:
# Mangga
# Anggur
# Apel
# Melon

# %%
for karakter in "IndonesiaID":
  print(karakter)
# Out:
# I
# n
# d
# o
# n
# e
# s
# i
# a
# I
# D

# %% [markdown]
# Break dan Continue

# %%
for i in range(10,20):
  # skip jika i == 15
  if (i == 15):
    continue

  print(i)
# Out:
# 10
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 19

# %%
for i in range(10,20):
  # hentikan jika i == 15
  if (i == 15):
    break

  print(i)
# Out:
# 10
# 11
# 12
# 13
# 14

# %% [markdown]
# For Else

# %%
listkota = ['Jakarta', 'Surabaya', 'Depok', 'Bekasi', 'Solo', 'Jogjakarta', 'Semarang', 'Makassar']

for kota in listkota:
  print(kota)

else:
  print('Toidak ada lagi item yang tersisa')
# Out:
# Jakarta
# Surabaya
# Depok
# Bekasi
# Solo
# Jogjakarta
# Semarang
# Makassar
# Toidak ada lagi item yang tersisa

# %% [markdown]
# For ... Else + Break

# %%
listkota = ['Jakarta', 'Surabaya', 'Depok', 'Bekasi', 'Solo', 'Jogjakarta', 'Semarang', 'Makassar']

kotaYangDicari = input('ketik nama kota yang kamu cari: ')

for i, kota in enumerate(listkota):
  # kita ubah katanya ke Lowercase agar
  # menjadi case insensitive
  if kota.lower() == kotaYangDicari.lower():
    print('Kota yang anda cari berada pada indeks', i)
    break
else:
  print('Maaf, kota yang anda cari tidak')
# Out:
# ketik nama kota yang kamu cari: Solo
# Kota yang anda cari berada pada indeks 4
