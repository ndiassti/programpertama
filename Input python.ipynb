# %% [markdown]
# Nilai Statis vs Nilau Inputan user

# %% [markdown]
# perhatikan contoh kode program dibawah ini

# %%
panjang = 10

# %%
lebar = 5

# %%
luas = panjang * lebar

# %%
print("luas =", luas)
# Out:
# luas = 50

# %% [markdown]
# Jika kode program di atas kita jalankan, kita akan mendapatkan output:

# %%
luas = 50

# %% [markdown]
# Membuat Input Pada Python

# %% [markdown]
# perhatikan contoh berikut

# %%
nama = input("masukan nama anda: ")
print('Halo,', nama,  'lucu selamat datang')
# Out:
# masukan nama anda: Nadia sasti
# Halo, Nadia sasti lucu selamat datang

# %% [markdown]
# pada program diatas:
#   1. kita membuat sebuah variabel yaitu variable**`nama`**
#   2. kemudian kita mengisi variabel **`nama`** tersebbut berdasrkan inputan dari user

# %% [markdown]
# Tipe data dari nilai input adalah string

# %% [markdown]
# Input

# %% [markdown]
# mari kita buktikan

# %%
nama = input('masukan nama anda:  ')
# Out:
# masukan nama anda:  Nadia sasti

# %%
print('Variabel nama bertipe data', type(nama))
# Out:
# Variabel nama bertipe data <class 'str'>

# %% [markdown]
# Jika kita masuka"Nadia Sasti" sebagai input maka kode program diatas akan menghasilkan output

# %% [markdown]
# masukan nama anda:  Nadia sasti
#
# Variabel nama bertipe data <class 'str'>

# %% [markdown]
# Untuk lebih menguatkan lagi, kita bisa mencoba kode program di bawah.

# %%
print('Kalkulator luas persegi panjang\n ')
panjang = input('Masukkan panjang: ')
lebar = input('Masukkan lebar: ')

print(' Luas =', panjang * lebar)
# Out:
# Kalkulator luas persegi panjang
#
# Masukkan panjang: 10
# Masukkan lebar: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-60ad4ec6394a> in <cell line: 5>()
#       3 lebar = input('Masukkan lebar: ')
#       4
# ----> 5 print(' Luas =', panjang * lebar)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# Jalankan kode program di atas, lalu masukkan angka **`10`** sebagai **`panjang`**., angka **`5`** sebagai **`lebar`** .

# %% [markdown]
# Program akan menghasilkan error:

# %% [markdown]
# Kenapa error? karena kita berusaha mengalikan dua buah nilai yang bertipe data string, dan hal itu akan menyebabkan error seperti di atas pada bahasa pemrograman python

# %%
print('Kalkulator luas persegi panjang\n ')
panjang = input('Masukkan panjang: ')
lebar = input('Masukkan lebar: ')

print(' Luas =', panjang * lebar)
# Out:
# Kalkulator luas persegi panjang
#
# Masukkan panjang: 10
# Masukkan lebar: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-60ad4ec6394a> in <cell line: 5>()
#       3 lebar = input('Masukkan lebar: ')
#       4
# ----> 5 print(' Luas =', panjang * lebar)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# soulusinya

# %% [markdown]
# Lalu bagaimana solusinya jika kita ingin mengalikan dua buah bilangan hasil dari input user

# %%
type(10)
# Out:
# int

# %% [markdown]
# Caranya adalah dengan mengkonversi tipe data!

# %%
type('10')
# Out:
# str

# %% [markdown]
# Kita bisa mengkonversi tipe data string menjadi integer menggunakan fungsi int().

# %%
type(int('10'))
# Out:
# int

# %% [markdown]
# Contoh

# %%
print('Kalkulator luas persegi panjang\n ')
panjang = input('Masukkan panjang: ')
lebar = input('Masukkan lebar: ')
print(' luas =', int(panjang) * int(lebar))
# Out:
# Kalkulator luas persegi panjang
#
# Masukkan panjang: 10
# Masukkan lebar: 5
#  luas = 50

# %% [markdown]
# Ketika dijalankan sistem tidak lagi menampilkan error😁
