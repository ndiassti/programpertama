# %%
#tuple

# %%
#apa itu tuple?

# %%
#1. Tuple adalah 1 dari 4 tipe data kolektif pada python

# %%
#2. Nilai tuple tidak bisa dirubah

# %%
#3. Nilai tuple tidak bisa ditambah

# %%
#4. Nilai tuple adalah nilai fix/asli/tetap

# %%
#penjelasan dan metode tuple

# %%
#1. tuple kosong

# %%
tuple_kosong = ()

# %%
print (tuple_kosong)
# Out:
# ()

# %%
#2.tuple_boneka

# %%
tuple_boneka = ("lotso", "lumba-lumba", "kucing", "hamster", "kuda poni")

# %%
print(tuple_boneka)
# Out:
# ('lotso', 'lumba-lumba', 'kucing', 'hamster', 'kuda poni')

# %%
tuple_boneka.count('kucing')
# Out:
# 1

# %%
#fungsi count adalah untuk menghitung ada berapa jumlah item yang dicari di dalam data tuple

# %%
#contoh

# %%
tuple_boneka = ("lotso","lotso", "lumba-lumba", "kucing", "hamster", "kuda poni")

# %%
tuple_boneka.count('lotso')
# Out:
# 2

# %%
#nah ketika lotso ditambah menjadi 2, maka count(jumlah) dari item lotso menjadi 2

# %%
tuple_boneka = ("lotso", "lumba-lumba", "kucing", "hamster", "kuda poni")

# %%
print(tuple_boneka)
# Out:
# ('lotso', 'lumba-lumba', 'kucing', 'hamster', 'kuda poni')

# %%
tuple_boneka.index('lumba-lumba')
# Out:
# 1

# %%
#index berfungsi untuk mengetahui urutan keberapa item yang dicari di dalam data tuple

# %%
#contoh

# %%
tuple_boneka.index('kucing')
# Out:
# 2

# %%
#setiap hitungan urutan item selalu diawali dari 0

# %%
print(len(tuple_boneka))
# Out:
# 5

# %%
#fungsi len untuk mengetahui jumlah keseluruhan item yang ada dalam data tuple

# %%
for z in tuple_boneka:
    print(z)
# Out:
# lotso
# lumba-lumba
# kucing
# hamster
# kuda poni

# %%
#for ... in dan print(...) berfungsi untuk menampilkan seluruh data tuple menyusun ke bawah

# %%
#syaratnya for ... in dan print(...) harus menggunakan huruf yang sama dan formatnya juga benar

# %%
#kita juga bisa menggabung data tuple a dan b....n

# %%
#contoh

# %%
tuple_boneka = ("lotso", "lumba-lumba", "kucing", "hamster", "kuda poni")

# %%
tuple_angka = ("1000", "2000", "3000", "4000", "5000")

# %%
tuple_campur = tuple_boneka + tuple_angka

# %%
print(tuple_campur)
# Out:
# ('lotso', 'lumba-lumba', 'kucing', 'hamster', 'kuda poni', '1000', '2000', '3000', '4000', '5000')

# %%
#sebenarnya list dan tuple pada data python hampir sama

# %%
#contoh list dan python

# %%
list_boneka = ["lotso", "lumba-lumba", "kucing", "hamster", "kuda poni"]

# %%
print(list_boneka)
# Out:
# ['lotso', 'lumba-lumba', 'kucing', 'hamster', 'kuda poni']

# %%
list_boneka.append('buaya')

# %%
print(list_boneka)
# Out:
# ['lotso', 'lumba-lumba', 'kucing', 'hamster', 'kuda poni', 'buaya']

# %%
list_boneka.remove('buaya')

# %%
print(list_boneka)
# Out:
# ['lotso', 'lumba-lumba', 'kucing', 'hamster', 'kuda poni']

# %%
#contoh tuple

# %%
tuple_boneka = ("lotso", "lumba-lumba", "kucing", "hamster", "kuda poni")

# %%
print(tuple_boneka)
# Out:
# ('lotso', 'lumba-lumba', 'kucing', 'hamster', 'kuda poni')

# %%
tuple_boneka.append("buaya")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-179f2e0a07d0> in <cell line: 1>()
# ----> 1 tuple_boneka.append("buaya")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tuple_boneka.remove(buaya)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-a63a1826ba92> in <cell line: 1>()
# ----> 1 tuple_boneka.remove(buaya)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
#nah seperti contoh diatas yang membedakan tuple dan list dalam data python adalah penambahan(append) dan pengurangan(remove)

# %%
#ketika item list ditambah item baru maka hasilnya akan keluar namun sebaliknya ketika tuple ditambah item baru, maka hasilnya akan error

# %%
#begitu pula dengan pengurangan(remove)

# %%
#tuple

# %%
#tuple 1

# %%
tuple_hewan = ("ikan", "beruang", "lumba-lumba", "hamster", "pinguin", "panda")

# %%
print(tuple_hewan)
# Out:
# ('ikan', 'beruang', 'lumba-lumba', 'hamster', 'pinguin', 'panda')

# %%
print(len(tuple_hewan))
# Out:
# 6

# %%
print(tuple_hewan[1])
# Out:
# beruang

# %%
print(tuple_hewan[0])
# Out:
# ikan

# %%
print(tuple_hewan[2])
# Out:
# lumba-lumba

# %%
print(tuple_hewan[4])
# Out:
# pinguin

# %%
print(tuple_hewan[-1])
# Out:
# panda

# %%
print(tuple_hewan[-3])
# Out:
# hamster

# %%
print(tuple_hewan[-5])
# Out:
# beruang

# %%
print(tuple_hewan[0:1])
print(tuple_hewan[0:2])
print(tuple_hewan[1:3])
print(tuple_hewan[0:-1])
print(tuple_hewan[-1:-3])
print(tuple_hewan[-1:3])
print(tuple_hewan[-3:-1])
# Out:
# ('ikan',)
# ('ikan', 'beruang')
# ('beruang', 'lumba-lumba')
# ('ikan', 'beruang', 'lumba-lumba', 'hamster', 'pinguin')
# ()
# ()
# ('hamster', 'pinguin')

# %%
print(tuple_hewan[0:])
print(tuple_hewan[1:])
print(tuple_hewan[2:])
print(tuple_hewan[3:])
print(tuple_hewan[:0])
print(tuple_hewan[:1])
print(tuple_hewan[:2])
print(tuple_hewan[:3])
print(tuple_hewan[:4])
# Out:
# ('ikan', 'beruang', 'lumba-lumba', 'hamster', 'pinguin', 'panda')
# ('beruang', 'lumba-lumba', 'hamster', 'pinguin', 'panda')
# ('lumba-lumba', 'hamster', 'pinguin', 'panda')
# ('hamster', 'pinguin', 'panda')
# ()
# ('ikan',)
# ('ikan', 'beruang')
# ('ikan', 'beruang', 'lumba-lumba')
# ('ikan', 'beruang', 'lumba-lumba', 'hamster')

# %%
print('')

# %%
print(tuple_hewan)
# Out:
# ('ikan', 'beruang', 'lumba-lumba', 'hamster', 'pinguin', 'panda')

# %%
#tuple2

# %%
#tuple_campur

# %%
tuple_hewanlaut = ("gurita", "penyu", "lumba-lumba")

# %%
tuple_hewandarat = ("beruang", "kucing", "hamster")

# %%
tuple_campur = tuple_hewanlaut + tuple_hewandarat

# %%
print(tuple_campur)
# Out:
# ('gurita', 'penyu', 'lumba-lumba', 'beruang', 'kucing', 'hamster')

# %%
tuple_campur.count ('lumba-lumba')
# Out:
# 1

# %%
tuple_campur.index ('beruang')
# Out:
# 3

# %%
#jadi kesimpulannya tuple tidak befungsi atau tidak berkerja apabila didalam proses pengerjaan ada penambahan dan pengurangan dan sebgainya

# %%
#karena nilai atau item di dalam data tuple adalah item fix/asli/tetap yang tidak bisa ditambah atau dikurangkan

# %%
#nilai atau item pada tuple hanya bisa bertambah apabila menggabungkan dua buah data tuple
