# %%
# Membuat Fungsi
def salam():
  print ("Hello, ini Lala")

# %%
## Pemanggilan Fungsi
salam()
salam()
salam()
# Out:
# Hello, ini Lala
# Hello, ini Lala
# Hello, ini Lala

# %%
def salam(ucapan):
  print(ucapan)
salam("Selamat Siang Lala")
# Out:
# Selamat Siang Lala

# %%
# Membuat fungsi dengan parameter
def luas_segitiga(alas,tinggi):
    luas = (alas * tinggi) / 2
    print ("Luas segitiga: %f" % luas)

# %%
# Pemanggilan fungsi
luas_segitiga(5, 6)
# Out:
# Luas segitiga: 15.000000

# %%
def luas_persegi(sisi):
    luas = sisi * sisi
    return luas

# %%
# pemanggil fungsi
print ("Luas persegi: %d" % luas_persegi(8))
# Out:
# Luas persegi: 64

# %%
# membuat variabel global
nama = "Belajar Kode"
versi = "1.0.0"

def help():
    # ini variabel lokal
    nama = "Programku"
    versi = "1.0.1"
    # mengakses variabel lokal
    print ("Nama: %s" % nama)
    print ("Versi: %s" % versi)

# %%
# mengakses variabel global
print ("Nama: %s" % nama)
print ("Versi: %s" % versi)

# memanggil fungsi help()
help()
# Out:
# Nama: Belajar Kode
# Versi: 1.0.0
# Nama: Programku
# Versi: 1.0.1

# %%
# membuat variabel global
nama = "Nama, Tanggal lahir"
versi = "Nadia Sasti, 16 Juni"

def help():
    # ini variabel lokal
    nama = "Hobi, jurusan, tempat tinggal"
    versi = "Membaca, Ilmu Komputer, Kacung"
    # mengakses variabel lokal
    print ("Nama: %s" % nama)
    print ("Versi: %s" % versi)

# %%
# mengakses variabel global
print ("Nama: %s" % nama)
print ("Versi: %s" % versi)

# memanggil fungsi help()
help()
# Out:
# Nama: Nama, Tanggal lahir
# Versi: Nadia Sasti, 16 Juni
# Nama: Hobi, jurusan, tempat tinggal
# Versi: Membaca, Ilmu Komputer, Kacung

# %%
buku = []
# fungsi untuk menampilkan semua data
def show_data():
    if len(buku) <= 0:
        print("BELUM ADA DATA")
    else:
        for indeks in range(len(buku)):
            print("[{}] {}".format(indeks, buku[indeks]))

# fungsi untuk menambah data
def insert_data():
    buku_baru = input("Judul Buku:")
    buku.append(buku_baru)

# fungsi untuk edit data
def edit_data():
    show_data()
    indeks = int(input("Inputan ID buku"))
    if indeks > len(buku):
      print("ID salah")
    else:
      judul_baru = input("Judul Buku:")
      buku[indeks] = judul_baru

def delete_data():
    show_data()
    indeks = int(input("Inputan ID buku"))
    if indeks > len(buku):
      print("ID salah")
    else:
      buku.remove(buku[indeks])

# fungsi untuk menampilkan menu
def show_menu():
    print("\n")
    print("---------- MENU ----------")
    print("[1] Show Data")
    print("[2] Insert Data")
    print("[3] Edit Data")
    print("[4] Delete Data12345678
    ")
    print("[5] Exit")

    menu = input("PILIH MENU>")
    print("\n")

    if int(menu) == 1:
      show_data()
    elif int(menu) == 2:
      insert_data()
    elif int(menu) == 3:
      edit_data()
    elif int(menu) == 4:
      delete_data()
    elif int(menu) == 5:
     exit()
    else:
      print("Salah pilih!")

if __name__ == "__main__":

    while True:
        show_menu()
# Out:
# ---------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU>2
#
#
# Judul Buku:Assalamualaikum Oppa!
#
#
# ---------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU>1
#
#
# [0] Assalamualaikum Oppa!
#
#
# ---------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU>2
#
#
# Judul Buku:Assalamualaikum Oppa!
#
#
# ---------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU>3
#
#
# [0] Assalamualaikum Oppa!
# [1] Assalamualaikum Oppa!
# Inputan ID buku12345678
# ID salah
#
#
# ---------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU>5
#
#
#
#
# ---------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
