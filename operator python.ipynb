# %% [markdown]
# Operator Aritmatika

# %%
#contoh pemrograman

# %%
a, b = 10,3

# %%
#Menjumlahkan nilai operan

# %%
print(a, '+', b, '=', a + b)
# Out:
# 10 + 3 = 13

# %%
#Mengurangkan nilai operan

# %%
print(a, '-', b, '=', a - b)
# Out:
# 10 - 3 = 7

# %%
#Mengalikan nilai operan

# %%
print(a, '*', b, '=', a* b)
# Out:
# 10 * 3 = 30

# %%
#Membagi nilai operan

# %%
print(a, '/', b, '=', a / b)
# Out:
# 10 / 3 = 3.3333333333333335

# %%
#Menghitung sisa bagi dari operan

# %%
print(a, '%', b, '=', a % b)
# Out:
# 10 % 3 = 1

# %%
#Menghitung pangkat dari operan

# %%
print(a, '**', b, '=', a ** b)
# Out:
# 10 ** 3 = 1000

# %%
#Membagi operan lalu membulatkannya dengan menghapus angka dibelakang koma

# %%
print(a, '//', b, '=', a // b)
# Out:
# 10 // 3 = 3

# %% [markdown]
# Operator Komparasi atau Perbandingan

# %%
#contoh pemrograman

# %%
a, b = 6, 12

# %%
#Lebih dari

# %%
print(a, '>', b, '=', a > b)
# Out:
# 6 > 12 = False

# %%
#Kurang dari

# %%
print(a, '<', b, '=', a < b)
# Out:
# 6 < 12 = True

# %%
#Sama dengan

# %%
print(a, '==', b, '=', a == b)
# Out:
# 6 == 12 = False

# %%
#Tidak sama dengan

# %%
print(a, '!=', b, '=', a != b)
# Out:
# 6 != 12 = True

# %%
#Lebih dari sama dengan

# %%
print(a, '>=', b, '=', a >= b)
# Out:
# 6 >= 12 = False

# %%
#Kurang dari atau sama dengan

# %%
print(a, '<=', b, '=', a <= b)
# Out:
# 6 <= 12 = True

# %% [markdown]
# Operator Penugasan

# %%
#contoh pemrograman

# %%
#penugasan pertama
a = 10
print('a = 10 -> ', a)
# Out:
# a = 10 ->  10

# %%
a += 5
print('a += 5 -> ', a)
# Out:
# a += 5 ->  15

# %%
a -= 3
print('a -= 3 ->', a)
# Out:
# a -= 3 -> 12

# %%
a *= 7
print ('a *= 7 ->', a)
# Out:
# a *= 7 -> 84

# %%
a /= 9
print ('a /= 8 ->', a)
# Out:
# a /= 8 -> 9.333333333333334

# %%
# karena a jadi float, kita ubah lagi menjadi integar
a = int(a)

# %%
a %= 10
print('a %= 10 ->', a)
# Out:
# a %= 10 -> 9

# %%
a //= 8
print('a //= 8 ->', a)
# Out:
# a //= 8 -> 1

# %%
a **= 6
print('a **= 6 ->', a)
# Out:
# a **= 6 -> 1

# %% [markdown]
# Operator Logika

# %%
#contoh pemrograman

# %%
print(True and True)
# Out:
# True

# %%
print(1 + 2 == 3 and True)
# Out:
# True

# %%
print('---')
# Out:
# ---

# %%
print(False or 1 > 6)
# Out:
# False

# %%
print(False or 6 > 1)
# Out:
# True

# %%
print('----')
# Out:
# ----

# %%
print(not(1 > 6))
# Out:
# True

# %%
print(not(1 < 6))
# Out:
# False

# %% [markdown]
# Operarator keanggotaaan

# %%
#contoh pemrograman

# %%
perusahaan ='Microsoft'

# %%
list_pulau = ['jawa', 'sumatera', 'sulawesi']

# %%
# ini adaL ah dictionary, insyaal Lah akan kita peLajar

# %%
#di pertemuan - pertemuan yang akan datang

# %%
mahasiswa = {
    'nama ': 'Lendis Fabri',
    'asal ' : 'Lamongan'
}

# %%
print(
  "Apakah 'c' ada di variabel perusahaan?",
  'c' in perusahaan
)
# Out:
# Apakah 'c' ada di variabel perusahaan? True

# %%
print(

  "Apakah 'z' tidak ada di variabel perusahaan?"
  'c' not in perusahaan
)
# Out:
# True

# %%
print(
  "Apakah 'Madura' tidak ada di variabel list_pulau?",
  'Madura' not in perusahaan
)
# Out:
# Apakah 'Madura' tidak ada di variabel list_pulau? True

# %%
print(
  "Apakah atribut 'nama' ada di variabel mahasiswa?",
  'nama' in mahasiswa
)
# Out:
# Apakah atribut 'nama' ada di variabel mahasiswa? False

# %% [markdown]
# Operator Identitas

# %%
#contoh pemrograman

# %%
a = 5
b = 5
nama_a = 'budi'
nama_b = 'budi'

# %%
#output True

# %%
print('a is b', a is b)
# Out:
# a is b True

# %%
#output False

# %%
print('a is not b', a is not b)
# Out:
# a is not b False

# %%
#otput True

# %%
print('nama_a is nama_b', nama_a is nama_b)
# Out:
# nama_a is nama_b True

# %%
#output False

# %%
print('nama_a is not nama_b', nama_a is not nama_b)
# Out:
# nama_a is not nama_b False

# %%
>>> id('merah')
140442358081648
>>> id('merah ')
140442358081776
>>>
# Out:
# 140442358081776

# %%
#Contoh berikutnya untuk nilai integer:

# %%
>>> id(10)
140442360371792
>>> id(10)
140442360371792
>>>
# Out:
# 140442360371792
